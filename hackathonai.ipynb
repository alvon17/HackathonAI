# %%
#Import library
from tensorflow.keras.models import Model, Sequential, load_model
from tensorflow.keras.layers import Dense, Activation, Conv2D, Flatten, Dropout, MaxPooling2D, MaxPool2D, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras import regularizers
from tensorflow.keras import optimizers
from sklearn.metrics import f1_score
from tensorflow.keras import layers
from tensorflow import keras
from keras.callbacks import ModelCheckpoint
from tensorflow.keras import regularizers

import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import zipfile
import tensorflow as tf

# %%
# #Extract compressed dataset
# with zipfile.ZipFile('/content/train.zip', 'r') as zip_ref:
#     zip_ref.extractall('/content/')

# with zipfile.ZipFile('/content/test.zip', 'r') as zip_ref:
#     zip_ref.extractall('/content/')

# %%
#Load dataset
traindf=pd.read_csv('../input/socs-hackathon-ai-preliminary-phase/train.csv',dtype=str)
testdf=pd.read_csv('../input/socs-hackathon-ai-preliminary-phase/test.csv',dtype=str)

# %%
#Create data generator
#Divide train data into train and validation data
# img_size = (224, 224)
datagen=ImageDataGenerator(
        rescale=1. / 255,
#         horizontal_flip=True,
#         vertical_flip=True,
#         zoom_range=0.1,
        validation_split=0.2)

train_generator=datagen.flow_from_dataframe(
      dataframe=traindf,
      directory="../input/socs-hackathon-ai-preliminary-phase/train/train",
      x_col="data",
      y_col="label",
      subset="training",
      batch_size=32,
      seed=42,
#       image_size=img_size,
      shuffle=True,
      class_mode="categorical",
      target_size=(224, 224))

valid_generator=datagen.flow_from_dataframe(
      dataframe=traindf,
      directory="../input/socs-hackathon-ai-preliminary-phase/train/train",
      x_col="data",
      y_col="label",
      subset="validation",
      batch_size=32,
      seed=42,
#       image_size=img_size,
      shuffle=True,
      class_mode="categorical",
      target_size=(224, 224))

test_datagen=ImageDataGenerator(rescale=1./255.)

test_generator=test_datagen.flow_from_dataframe(
      dataframe=testdf,
      directory="../input/socs-hackathon-ai-preliminary-phase/test/test",
      x_col="data",
      y_col=None,
      batch_size=1,
      seed=42,
#       image_size=img_size,
      shuffle=False,
      class_mode=None,
      target_size=(224, 224))
# Out:
# Found 11152 validated image filenames belonging to 11 classes.
# Found 2788 validated image filenames belonging to 11 classes.
# Found 9829 validated image filenames.

# %%
#Create evaluation metric function (F1-score)
from keras import backend as K

def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
# AUTOTUNE = tf.data.AUTOTUNE

# train_ds = train_generator.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
# val_ds = val_generator.cache().prefetch(buffer_size=AUTOTUNE)
# test_ds = test_generator.cache().prefetch(buffer_size=AUTOTUNE)

# %%
# data_augmentation = keras.Sequential(
#   [
#     layers.RandomFlip("horizontal"),
#     layers.RandomRotation(0.1),
#     layers.RandomZoom(0.1),
#   ]
# )

# %%
# preprocess_input = keras.applications.vgg16.preprocess_input

# %%
IMG_SHAPE = (224, 224, 3)
base_model = keras.applications.vgg16.VGG16(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# 58900480/58889256 [==============================] - 0s 0us/step

# %%
base_model.trainable = True

# %%
#Define the machine learning model
inputs = keras.Input(shape=(224, 224, 3))
# x = data_augmentation(inputs)
# x = preprocess_input(inputs)
x = base_model(inputs)
x = layers.Flatten(name="flatten")(x)
x = layers.Dense(1024, activation="relu")(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(11, activation="softmax")(x)

model1 = keras.Model(inputs, outputs)

# %%
model1.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# vgg16 (Functional)           (None, 7, 7, 512)         14714688
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              25691136
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 11)                11275
# =================================================================
# Total params: 40,417,099
# Trainable params: 40,417,099
# Non-trainable params: 0
# _________________________________________________________________

# %%
model1.compile(optimizers.Adam(learning_rate=0.0001, decay=1e-6),loss="categorical_crossentropy",metrics=["accuracy", f1_m])

# %%
checkpoint = ModelCheckpoint("model1_weights.h5", monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

# %%
#Train the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
STEP_SIZE_TEST=test_generator.n//test_generator.batch_size
hist1=model1.fit(train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    epochs=50,
                    callbacks = callbacks_list
)
# Out:
# Epoch 1/50
# 348/348 [==============================] - 86s 232ms/step - loss: 1.1039 - accuracy: 0.6024 - f1_m: 0.5607 - val_loss: 0.6102 - val_accuracy: 0.7730 - val_f1_m: 0.7663
#
# Epoch 00001: val_accuracy improved from -inf to 0.77299, saving model to model1_weights.h5
# Epoch 2/50
# 348/348 [==============================] - 78s 225ms/step - loss: 0.5187 - accuracy: 0.8007 - f1_m: 0.7979 - val_loss: 0.3767 - val_accuracy: 0.8473 - val_f1_m: 0.8435
#
# Epoch 00002: val_accuracy improved from 0.77299 to 0.84734, saving model to model1_weights.h5
# Epoch 3/50
# 348/348 [==============================] - 79s 226ms/step - loss: 0.3470 - accuracy: 0.8601 - f1_m: 0.8597 - val_loss: 0.3141 - val_accuracy: 0.8710 - val_f1_m: 0.8713
#
# Epoch 00003: val_accuracy improved from 0.84734 to 0.87105, saving model to model1_weights.h5
# Epoch 4/50
# 348/348 [==============================] - 79s 226ms/step - loss: 0.2540 - accuracy: 0.8924 - f1_m: 0.8916 - val_loss: 0.2746 - val_accuracy: 0.8833 - val_f1_m: 0.8822
#
# Epoch 00004: val_accuracy improved from 0.87105 to 0.88326, saving model to model1_weights.h5
# Epoch 5/50
# 348/348 [==============================] - 78s 225ms/step - loss: 0.1865 - accuracy: 0.9212 - f1_m: 0.9207 - val_loss: 0.2167 - val_accuracy: 0.9106 - val_f1_m: 0.9134
#
# Epoch 00005: val_accuracy improved from 0.88326 to 0.91056, saving model to model1_weights.h5
# Epoch 6/50
# 348/348 [==============================] - 78s 225ms/step - loss: 0.1546 - accuracy: 0.9354 - f1_m: 0.9348 - val_loss: 0.2260 - val_accuracy: 0.9095 - val_f1_m: 0.9104
#
# Epoch 00006: val_accuracy did not improve from 0.91056
# Epoch 7/50
# 348/348 [==============================] - 78s 225ms/step - loss: 0.1247 - accuracy: 0.9469 - f1_m: 0.9471 - val_loss: 0.1988 - val_accuracy: 0.9199 - val_f1_m: 0.9196
#
# Epoch 00007: val_accuracy improved from 0.91056 to 0.91990, saving model to model1_weights.h5
# Epoch 8/50
# 348/348 [==============================] - 78s 225ms/step - loss: 0.1089 - accuracy: 0.9518 - f1_m: 0.9519 - val_loss: 0.2658 - val_accuracy: 0.9070 - val_f1_m: 0.9071
#
# Epoch 00008: val_accuracy did not improve from 0.91990
# Epoch 9/50
# 348/348 [==============================] - 79s 226ms/step - loss: 0.1038 - accuracy: 0.9580 - f1_m: 0.9570 - val_loss: 0.2159 - val_accuracy: 0.9066 - val_f1_m: 0.9084
#
# Epoch 00009: val_accuracy did not improve from 0.91990
# Epoch 10/50
# 348/348 [==============================] - 79s 226ms/step - loss: 0.0823 - accuracy: 0.9655 - f1_m: 0.9654 - val_loss: 0.2201 - val_accuracy: 0.9177 - val_f1_m: 0.9179
#
# Epoch 00010: val_accuracy did not improve from 0.91990
# Epoch 11/50
# 348/348 [==============================] - 78s 225ms/step - loss: 0.0779 - accuracy: 0.9678 - f1_m: 0.9682 - val_loss: 0.2398 - val_accuracy: 0.9127 - val_f1_m: 0.9115
#
# Epoch 00011: val_accuracy did not improve from 0.91990
# Epoch 12/50
# 348/348 [==============================] - 79s 226ms/step - loss: 0.0705 - accuracy: 0.9710 - f1_m: 0.9713 - val_loss: 0.2304 - val_accuracy: 0.9174 - val_f1_m: 0.9165
#
# Epoch 00012: val_accuracy did not improve from 0.91990
# Epoch 13/50
# 348/348 [==============================] - 78s 225ms/step - loss: 0.0576 - accuracy: 0.9776 - f1_m: 0.9773 - val_loss: 0.2395 - val_accuracy: 0.9242 - val_f1_m: 0.9249
#
# Epoch 00013: val_accuracy improved from 0.91990 to 0.92421, saving model to model1_weights.h5
# Epoch 14/50
# 348/348 [==============================] - 78s 225ms/step - loss: 0.0512 - accuracy: 0.9806 - f1_m: 0.9807 - val_loss: 0.1928 - val_accuracy: 0.9379 - val_f1_m: 0.9377
#
# Epoch 00014: val_accuracy improved from 0.92421 to 0.93786, saving model to model1_weights.h5
# Epoch 15/50
# 348/348 [==============================] - 79s 226ms/step - loss: 0.0652 - accuracy: 0.9772 - f1_m: 0.9768 - val_loss: 0.2203 - val_accuracy: 0.9332 - val_f1_m: 0.9333
#
# Epoch 00015: val_accuracy did not improve from 0.93786
# Epoch 16/50
# 348/348 [==============================] - 78s 225ms/step - loss: 0.0411 - accuracy: 0.9853 - f1_m: 0.9854 - val_loss: 0.2475 - val_accuracy: 0.9235 - val_f1_m: 0.9240
#
# Epoch 00016: val_accuracy did not improve from 0.93786
# Epoch 17/50
# 348/348 [==============================] - 78s 225ms/step - loss: 0.0444 - accuracy: 0.9841 - f1_m: 0.9842 - val_loss: 0.2729 - val_accuracy: 0.9221 - val_f1_m: 0.9227
#
# Epoch 00017: val_accuracy did not improve from 0.93786
# Epoch 18/50
# 348/348 [==============================] - 78s 225ms/step - loss: 0.0427 - accuracy: 0.9850 - f1_m: 0.9847 - val_loss: 0.3008 - val_accuracy: 0.9149 - val_f1_m: 0.9153
#
# Epoch 00018: val_accuracy did not improve from 0.93786
# Epoch 19/50
# 348/348 [==============================] - 78s 225ms/step - loss: 0.0387 - accuracy: 0.9873 - f1_m: 0.9871 - val_loss: 0.2727 - val_accuracy: 0.9282 - val_f1_m: 0.9284
#
# Epoch 00019: val_accuracy did not improve from 0.93786
# Epoch 20/50
# 348/348 [==============================] - 78s 225ms/step - loss: 0.0358 - accuracy: 0.9875 - f1_m: 0.9878 - val_loss: 0.2596 - val_accuracy: 0.9368 - val_f1_m: 0.9373
#
# Epoch 00020: val_accuracy did not improve from 0.93786
# Epoch 21/50
# 348/348 [==============================] - 78s 225ms/step - loss: 0.0201 - accuracy: 0.9924 - f1_m: 0.9924 - val_loss: 0.2302 - val_accuracy: 0.9357 - val_f1_m: 0.9358
#
# Epoch 00021: val_accuracy did not improve from 0.93786
# Epoch 22/50
# 348/348 [==============================] - 78s 225ms/step - loss: 0.0419 - accuracy: 0.9854 - f1_m: 0.9854 - val_loss: 0.2817 - val_accuracy: 0.9210 - val_f1_m: 0.9217
#
# Epoch 00022: val_accuracy did not improve from 0.93786
# Epoch 23/50
# 348/348 [==============================] - 78s 225ms/step - loss: 0.0246 - accuracy: 0.9915 - f1_m: 0.9914 - val_loss: 0.2229 - val_accuracy: 0.9285 - val_f1_m: 0.9289
#
# Epoch 00023: val_accuracy did not improve from 0.93786
# Epoch 24/50
# 348/348 [==============================] - 78s 225ms/step - loss: 0.0292 - accuracy: 0.9910 - f1_m: 0.9908 - val_loss: 0.2086 - val_accuracy: 0.9361 - val_f1_m: 0.9361
#
# Epoch 00024: val_accuracy did not improve from 0.93786
# Epoch 25/50
# 348/348 [==============================] - 78s 225ms/step - loss: 0.0197 - accuracy: 0.9942 - f1_m: 0.9940 - val_loss: 0.2779 - val_accuracy: 0.9282 - val_f1_m: 0.9286
#
# Epoch 00025: val_accuracy did not improve from 0.93786
# Epoch 26/50
# 348/348 [==============================] - 79s 226ms/step - loss: 0.0229 - accuracy: 0.9937 - f1_m: 0.9938 - val_loss: 0.2761 - val_accuracy: 0.9314 - val_f1_m: 0.9317
#
# Epoch 00026: val_accuracy did not improve from 0.93786
# Epoch 27/50
# 348/348 [==============================] - 78s 225ms/step - loss: 0.0206 - accuracy: 0.9933 - f1_m: 0.9933 - val_loss: 0.3983 - val_accuracy: 0.9170 - val_f1_m: 0.9165
#
# Epoch 00027: val_accuracy did not improve from 0.93786
# Epoch 28/50
# 348/348 [==============================] - 79s 226ms/step - loss: 0.0408 - accuracy: 0.9878 - f1_m: 0.9876 - val_loss: 0.2465 - val_accuracy: 0.9310 - val_f1_m: 0.9313
#
# Epoch 00028: val_accuracy did not improve from 0.93786
# Epoch 29/50
# 348/348 [==============================] - 78s 225ms/step - loss: 0.0145 - accuracy: 0.9944 - f1_m: 0.9944 - val_loss: 0.3746 - val_accuracy: 0.9253 - val_f1_m: 0.9264
#
# Epoch 00029: val_accuracy did not improve from 0.93786
# Epoch 30/50
# 348/348 [==============================] - 78s 225ms/step - loss: 0.0115 - accuracy: 0.9964 - f1_m: 0.9964 - val_loss: 0.3362 - val_accuracy: 0.9357 - val_f1_m: 0.9352
#
# Epoch 00030: val_accuracy did not improve from 0.93786
# Epoch 31/50
# 348/348 [==============================] - 79s 226ms/step - loss: 0.0208 - accuracy: 0.9935 - f1_m: 0.9934 - val_loss: 0.3086 - val_accuracy: 0.9239 - val_f1_m: 0.9239
#
# Epoch 00031: val_accuracy did not improve from 0.93786
# Epoch 32/50
# 348/348 [==============================] - 78s 225ms/step - loss: 0.0288 - accuracy: 0.9905 - f1_m: 0.9904 - val_loss: 0.2518 - val_accuracy: 0.9375 - val_f1_m: 0.9370
#
# Epoch 00032: val_accuracy did not improve from 0.93786
# Epoch 33/50
# 348/348 [==============================] - 78s 225ms/step - loss: 0.0098 - accuracy: 0.9971 - f1_m: 0.9971 - val_loss: 0.3386 - val_accuracy: 0.9400 - val_f1_m: 0.9399
#
# Epoch 00033: val_accuracy improved from 0.93786 to 0.94001, saving model to model1_weights.h5
# Epoch 34/50
# 348/348 [==============================] - 78s 225ms/step - loss: 0.0153 - accuracy: 0.9948 - f1_m: 0.9948 - val_loss: 0.3167 - val_accuracy: 0.9282 - val_f1_m: 0.9287
#
# Epoch 00034: val_accuracy did not improve from 0.94001
# Epoch 35/50
# 348/348 [==============================] - 78s 225ms/step - loss: 0.0176 - accuracy: 0.9940 - f1_m: 0.9941 - val_loss: 0.2934 - val_accuracy: 0.9325 - val_f1_m: 0.9322
#
# Epoch 00035: val_accuracy did not improve from 0.94001
# Epoch 36/50
# 348/348 [==============================] - 78s 225ms/step - loss: 0.0160 - accuracy: 0.9950 - f1_m: 0.9950 - val_loss: 0.3241 - val_accuracy: 0.9274 - val_f1_m: 0.9279
#
# Epoch 00036: val_accuracy did not improve from 0.94001
# Epoch 37/50
# 348/348 [==============================] - 78s 225ms/step - loss: 0.0226 - accuracy: 0.9932 - f1_m: 0.9933 - val_loss: 0.2867 - val_accuracy: 0.9325 - val_f1_m: 0.9333
#
# Epoch 00037: val_accuracy did not improve from 0.94001
# Epoch 38/50
# 348/348 [==============================] - 78s 225ms/step - loss: 0.0084 - accuracy: 0.9975 - f1_m: 0.9974 - val_loss: 0.3256 - val_accuracy: 0.9321 - val_f1_m: 0.9319
#
# Epoch 00038: val_accuracy did not improve from 0.94001
# Epoch 39/50
# 348/348 [==============================] - 79s 226ms/step - loss: 0.0292 - accuracy: 0.9906 - f1_m: 0.9908 - val_loss: 0.2479 - val_accuracy: 0.9436 - val_f1_m: 0.9439
#
# Epoch 00039: val_accuracy improved from 0.94001 to 0.94361, saving model to model1_weights.h5
# Epoch 40/50
# 348/348 [==============================] - 78s 225ms/step - loss: 0.0054 - accuracy: 0.9982 - f1_m: 0.9982 - val_loss: 0.2766 - val_accuracy: 0.9440 - val_f1_m: 0.9442
#
# Epoch 00040: val_accuracy improved from 0.94361 to 0.94397, saving model to model1_weights.h5
# Epoch 41/50
# 348/348 [==============================] - 78s 225ms/step - loss: 0.0297 - accuracy: 0.9914 - f1_m: 0.9913 - val_loss: 0.2965 - val_accuracy: 0.9318 - val_f1_m: 0.9324
#
# Epoch 00041: val_accuracy did not improve from 0.94397
# Epoch 42/50
# 348/348 [==============================] - 78s 225ms/step - loss: 0.0066 - accuracy: 0.9977 - f1_m: 0.9977 - val_loss: 0.2885 - val_accuracy: 0.9461 - val_f1_m: 0.9464
#
# Epoch 00042: val_accuracy improved from 0.94397 to 0.94612, saving model to model1_weights.h5
# Epoch 43/50
# 348/348 [==============================] - 78s 225ms/step - loss: 0.0080 - accuracy: 0.9977 - f1_m: 0.9977 - val_loss: 0.4056 - val_accuracy: 0.9177 - val_f1_m: 0.9191
#
# Epoch 00043: val_accuracy did not improve from 0.94612
# Epoch 44/50
# 348/348 [==============================] - 79s 226ms/step - loss: 0.0149 - accuracy: 0.9950 - f1_m: 0.9950 - val_loss: 0.2967 - val_accuracy: 0.9382 - val_f1_m: 0.9380
#
# Epoch 00044: val_accuracy did not improve from 0.94612
# Epoch 45/50
# 348/348 [==============================] - 78s 225ms/step - loss: 0.0119 - accuracy: 0.9966 - f1_m: 0.9965 - val_loss: 0.3651 - val_accuracy: 0.9282 - val_f1_m: 0.9296
#
# Epoch 00045: val_accuracy did not improve from 0.94612
# Epoch 46/50
# 348/348 [==============================] - 79s 225ms/step - loss: 0.0146 - accuracy: 0.9953 - f1_m: 0.9952 - val_loss: 0.3178 - val_accuracy: 0.9415 - val_f1_m: 0.9412
#
# Epoch 00046: val_accuracy did not improve from 0.94612
# Epoch 47/50
# 348/348 [==============================] - 79s 226ms/step - loss: 0.0054 - accuracy: 0.9986 - f1_m: 0.9986 - val_loss: 0.2735 - val_accuracy: 0.9443 - val_f1_m: 0.9441
#
# Epoch 00047: val_accuracy did not improve from 0.94612
# Epoch 48/50
# 348/348 [==============================] - 78s 225ms/step - loss: 0.0133 - accuracy: 0.9961 - f1_m: 0.9961 - val_loss: 0.2812 - val_accuracy: 0.9386 - val_f1_m: 0.9395
#
# Epoch 00048: val_accuracy did not improve from 0.94612
# Epoch 49/50
# 348/348 [==============================] - 78s 225ms/step - loss: 0.0220 - accuracy: 0.9932 - f1_m: 0.9931 - val_loss: 0.2606 - val_accuracy: 0.9407 - val_f1_m: 0.9412
#
# Epoch 00049: val_accuracy did not improve from 0.94612
# Epoch 50/50
# 348/348 [==============================] - 78s 225ms/step - loss: 0.0019 - accuracy: 0.9994 - f1_m: 0.9994 - val_loss: 0.2743 - val_accuracy: 0.9375 - val_f1_m: 0.9378
#
# Epoch 00050: val_accuracy did not improve from 0.94612

# %%
IMG_SHAPE = (224, 224, 3)
base_model2 = keras.applications.mobilenet.MobileNet(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')

# %%
base_model2.trainable = True

# %%
#Define the machine learning model
inputs = keras.Input(shape=(224, 224, 3))
# x = data_augmentation(inputs)
# x = preprocess_input(inputs)
x = base_model2(inputs)
x = layers.Flatten(name="flatten")(x)
x = layers.Dense(1024, activation="relu")(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(11, activation="softmax")(x)

model2 = keras.Model(inputs, outputs)

# %%
# model2 = Sequential()
# # model.add(keras.applications.ResNet50(include_top=False, weights='imagenet', input_shape=(224, 224, 3)))
# model2.add(Conv2D(32, (2, 2), padding='same',
#                  input_shape=(224,224,3)))
# model2.add(Activation('relu'))
# model2.add(BatchNormalization())
# model2.add(Conv2D(32, (2, 2)))
# model2.add(Activation('relu'))
# model2.add(BatchNormalization())
# model2.add(MaxPooling2D(pool_size=(2, 2)))
# model2.add(Dropout(0.25))
# model2.add(Conv2D(64, (2, 2), padding='same'))
# model2.add(Activation('relu'))
# model2.add(BatchNormalization())
# model2.add(Conv2D(64, (2, 2)))
# model2.add(Activation('relu'))
# model2.add(BatchNormalization())
# model2.add(MaxPooling2D(pool_size=(2, 2)))
# model2.add(Dropout(0.25))
# model2.add(Flatten())
# model2.add(Dense(512))
# model2.add(Activation('relu'))
# model2.add(Dropout(0.5))
# model2.add(Dense(11, activation='softmax'))

# %%
model2.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# mobilenet_1.00_224 (Function (None, 7, 7, 1024)        3228864
# _________________________________________________________________
# flatten (Flatten)            (None, 50176)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              51381248
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 11)                11275
# =================================================================
# Total params: 54,621,387
# Trainable params: 54,599,499
# Non-trainable params: 21,888
# _________________________________________________________________

# %%
model2.compile(optimizers.Adam(learning_rate=0.0001, decay=1e-6),loss="categorical_crossentropy",metrics=["accuracy", f1_m])

# %%
checkpoint = ModelCheckpoint("model2_weights.h5", monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

# %%
#Train the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
STEP_SIZE_TEST=test_generator.n//test_generator.batch_size
hist2=model2.fit(train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    epochs=50,
                    callbacks = callbacks_list
)
# Out:
# Epoch 1/50
# 348/348 [==============================] - 60s 165ms/step - loss: 1.0296 - accuracy: 0.7117 - f1_m: 0.7117 - val_loss: 0.6085 - val_accuracy: 0.7773 - val_f1_m: 0.7794
#
# Epoch 00001: val_accuracy improved from -inf to 0.77730, saving model to model2_weights.h5
# Epoch 2/50
# 348/348 [==============================] - 57s 165ms/step - loss: 0.3162 - accuracy: 0.8836 - f1_m: 0.8833 - val_loss: 0.3516 - val_accuracy: 0.8531 - val_f1_m: 0.8547
#
# Epoch 00002: val_accuracy improved from 0.77730 to 0.85309, saving model to model2_weights.h5
# Epoch 3/50
# 348/348 [==============================] - 58s 167ms/step - loss: 0.1833 - accuracy: 0.9307 - f1_m: 0.9302 - val_loss: 0.3402 - val_accuracy: 0.8675 - val_f1_m: 0.8696
#
# Epoch 00003: val_accuracy improved from 0.85309 to 0.86746, saving model to model2_weights.h5
# Epoch 4/50
# 348/348 [==============================] - 57s 165ms/step - loss: 0.1228 - accuracy: 0.9537 - f1_m: 0.9532 - val_loss: 0.3327 - val_accuracy: 0.8818 - val_f1_m: 0.8841
#
# Epoch 00004: val_accuracy improved from 0.86746 to 0.88182, saving model to model2_weights.h5
# Epoch 5/50
# 348/348 [==============================] - 58s 167ms/step - loss: 0.1133 - accuracy: 0.9597 - f1_m: 0.9599 - val_loss: 0.2991 - val_accuracy: 0.8912 - val_f1_m: 0.8911
#
# Epoch 00005: val_accuracy improved from 0.88182 to 0.89116, saving model to model2_weights.h5
# Epoch 6/50
# 348/348 [==============================] - 59s 169ms/step - loss: 0.1130 - accuracy: 0.9615 - f1_m: 0.9615 - val_loss: 0.3307 - val_accuracy: 0.8933 - val_f1_m: 0.8949
#
# Epoch 00006: val_accuracy improved from 0.89116 to 0.89332, saving model to model2_weights.h5
# Epoch 7/50
# 348/348 [==============================] - 58s 166ms/step - loss: 0.0766 - accuracy: 0.9721 - f1_m: 0.9721 - val_loss: 0.4202 - val_accuracy: 0.8804 - val_f1_m: 0.8813
#
# Epoch 00007: val_accuracy did not improve from 0.89332
# Epoch 8/50
# 348/348 [==============================] - 58s 166ms/step - loss: 0.0844 - accuracy: 0.9725 - f1_m: 0.9726 - val_loss: 0.4269 - val_accuracy: 0.8843 - val_f1_m: 0.8848
#
# Epoch 00008: val_accuracy did not improve from 0.89332
# Epoch 9/50
# 348/348 [==============================] - 58s 166ms/step - loss: 0.1142 - accuracy: 0.9651 - f1_m: 0.9653 - val_loss: 0.3142 - val_accuracy: 0.9005 - val_f1_m: 0.8999
#
# Epoch 00009: val_accuracy improved from 0.89332 to 0.90050, saving model to model2_weights.h5
# Epoch 10/50
# 348/348 [==============================] - 58s 165ms/step - loss: 0.0623 - accuracy: 0.9789 - f1_m: 0.9786 - val_loss: 0.3240 - val_accuracy: 0.9055 - val_f1_m: 0.9045
#
# Epoch 00010: val_accuracy improved from 0.90050 to 0.90553, saving model to model2_weights.h5
# Epoch 11/50
# 348/348 [==============================] - 59s 169ms/step - loss: 0.1091 - accuracy: 0.9705 - f1_m: 0.9706 - val_loss: 0.3892 - val_accuracy: 0.9037 - val_f1_m: 0.9055
#
# Epoch 00011: val_accuracy did not improve from 0.90553
# Epoch 12/50
# 348/348 [==============================] - 57s 165ms/step - loss: 0.0828 - accuracy: 0.9749 - f1_m: 0.9748 - val_loss: 0.5954 - val_accuracy: 0.8585 - val_f1_m: 0.8614
#
# Epoch 00012: val_accuracy did not improve from 0.90553
# Epoch 13/50
# 348/348 [==============================] - 57s 165ms/step - loss: 0.1132 - accuracy: 0.9725 - f1_m: 0.9726 - val_loss: 0.3619 - val_accuracy: 0.9070 - val_f1_m: 0.9073
#
# Epoch 00013: val_accuracy improved from 0.90553 to 0.90697, saving model to model2_weights.h5
# Epoch 14/50
# 348/348 [==============================] - 59s 169ms/step - loss: 0.0690 - accuracy: 0.9808 - f1_m: 0.9809 - val_loss: 0.2626 - val_accuracy: 0.9253 - val_f1_m: 0.9252
#
# Epoch 00014: val_accuracy improved from 0.90697 to 0.92529, saving model to model2_weights.h5
# Epoch 15/50
# 348/348 [==============================] - 58s 166ms/step - loss: 0.0366 - accuracy: 0.9889 - f1_m: 0.9889 - val_loss: 0.3335 - val_accuracy: 0.9253 - val_f1_m: 0.9251
#
# Epoch 00015: val_accuracy did not improve from 0.92529
# Epoch 16/50
# 348/348 [==============================] - 58s 168ms/step - loss: 0.0605 - accuracy: 0.9830 - f1_m: 0.9829 - val_loss: 0.4740 - val_accuracy: 0.9009 - val_f1_m: 0.9006
#
# Epoch 00016: val_accuracy did not improve from 0.92529
# Epoch 17/50
# 348/348 [==============================] - 58s 166ms/step - loss: 0.0759 - accuracy: 0.9815 - f1_m: 0.9815 - val_loss: 0.3862 - val_accuracy: 0.9088 - val_f1_m: 0.9091
#
# Epoch 00017: val_accuracy did not improve from 0.92529
# Epoch 18/50
# 348/348 [==============================] - 58s 168ms/step - loss: 0.0743 - accuracy: 0.9821 - f1_m: 0.9822 - val_loss: 0.2563 - val_accuracy: 0.9339 - val_f1_m: 0.9334
#
# Epoch 00018: val_accuracy improved from 0.92529 to 0.93391, saving model to model2_weights.h5
# Epoch 19/50
# 348/348 [==============================] - 58s 166ms/step - loss: 0.0505 - accuracy: 0.9872 - f1_m: 0.9872 - val_loss: 0.3574 - val_accuracy: 0.9217 - val_f1_m: 0.9222
#
# Epoch 00019: val_accuracy did not improve from 0.93391
# Epoch 20/50
# 348/348 [==============================] - 57s 164ms/step - loss: 0.0829 - accuracy: 0.9835 - f1_m: 0.9836 - val_loss: 0.3093 - val_accuracy: 0.9224 - val_f1_m: 0.9227
#
# Epoch 00020: val_accuracy did not improve from 0.93391
# Epoch 21/50
# 348/348 [==============================] - 58s 165ms/step - loss: 0.0556 - accuracy: 0.9856 - f1_m: 0.9856 - val_loss: 0.2952 - val_accuracy: 0.9278 - val_f1_m: 0.9283
#
# Epoch 00021: val_accuracy did not improve from 0.93391
# Epoch 22/50
# 348/348 [==============================] - 59s 169ms/step - loss: 0.0355 - accuracy: 0.9901 - f1_m: 0.9903 - val_loss: 0.3140 - val_accuracy: 0.9339 - val_f1_m: 0.9344
#
# Epoch 00022: val_accuracy did not improve from 0.93391
# Epoch 23/50
# 348/348 [==============================] - 58s 165ms/step - loss: 0.0388 - accuracy: 0.9905 - f1_m: 0.9904 - val_loss: 0.3661 - val_accuracy: 0.9325 - val_f1_m: 0.9326
#
# Epoch 00023: val_accuracy did not improve from 0.93391
# Epoch 24/50
# 348/348 [==============================] - 59s 169ms/step - loss: 0.0766 - accuracy: 0.9829 - f1_m: 0.9830 - val_loss: 0.2817 - val_accuracy: 0.9253 - val_f1_m: 0.9254
#
# Epoch 00024: val_accuracy did not improve from 0.93391
# Epoch 25/50
# 348/348 [==============================] - 59s 168ms/step - loss: 0.0473 - accuracy: 0.9884 - f1_m: 0.9884 - val_loss: 0.3521 - val_accuracy: 0.9318 - val_f1_m: 0.9314
#
# Epoch 00025: val_accuracy did not improve from 0.93391
# Epoch 26/50
# 348/348 [==============================] - 58s 166ms/step - loss: 0.0476 - accuracy: 0.9893 - f1_m: 0.9893 - val_loss: 0.4364 - val_accuracy: 0.9203 - val_f1_m: 0.9205
#
# Epoch 00026: val_accuracy did not improve from 0.93391
# Epoch 27/50
# 348/348 [==============================] - 58s 167ms/step - loss: 0.0543 - accuracy: 0.9882 - f1_m: 0.9883 - val_loss: 0.3287 - val_accuracy: 0.9325 - val_f1_m: 0.9322
#
# Epoch 00027: val_accuracy did not improve from 0.93391
# Epoch 28/50
# 348/348 [==============================] - 58s 166ms/step - loss: 0.0464 - accuracy: 0.9889 - f1_m: 0.9890 - val_loss: 0.3999 - val_accuracy: 0.9296 - val_f1_m: 0.9296
#
# Epoch 00028: val_accuracy did not improve from 0.93391
# Epoch 29/50
# 348/348 [==============================] - 58s 166ms/step - loss: 0.0539 - accuracy: 0.9891 - f1_m: 0.9891 - val_loss: 0.3693 - val_accuracy: 0.9289 - val_f1_m: 0.9290
#
# Epoch 00029: val_accuracy did not improve from 0.93391
# Epoch 30/50
# 348/348 [==============================] - 58s 168ms/step - loss: 0.0395 - accuracy: 0.9905 - f1_m: 0.9905 - val_loss: 0.2992 - val_accuracy: 0.9382 - val_f1_m: 0.9387
#
# Epoch 00030: val_accuracy improved from 0.93391 to 0.93822, saving model to model2_weights.h5
# Epoch 31/50
# 348/348 [==============================] - 58s 166ms/step - loss: 0.0480 - accuracy: 0.9895 - f1_m: 0.9895 - val_loss: 0.3347 - val_accuracy: 0.9371 - val_f1_m: 0.9371
#
# Epoch 00031: val_accuracy did not improve from 0.93822
# Epoch 32/50
# 348/348 [==============================] - 58s 166ms/step - loss: 0.0424 - accuracy: 0.9904 - f1_m: 0.9905 - val_loss: 0.4526 - val_accuracy: 0.9246 - val_f1_m: 0.9243
#
# Epoch 00032: val_accuracy did not improve from 0.93822
# Epoch 33/50
# 348/348 [==============================] - 58s 165ms/step - loss: 0.0285 - accuracy: 0.9930 - f1_m: 0.9930 - val_loss: 0.3344 - val_accuracy: 0.9346 - val_f1_m: 0.9346
#
# Epoch 00033: val_accuracy did not improve from 0.93822
# Epoch 34/50
# 348/348 [==============================] - 58s 166ms/step - loss: 0.0413 - accuracy: 0.9917 - f1_m: 0.9917 - val_loss: 0.4938 - val_accuracy: 0.9264 - val_f1_m: 0.9267
#
# Epoch 00034: val_accuracy did not improve from 0.93822
# Epoch 35/50
# 348/348 [==============================] - 58s 167ms/step - loss: 0.0531 - accuracy: 0.9879 - f1_m: 0.9879 - val_loss: 0.7775 - val_accuracy: 0.9177 - val_f1_m: 0.9168
#
# Epoch 00035: val_accuracy did not improve from 0.93822
# Epoch 36/50
# 348/348 [==============================] - 58s 165ms/step - loss: 0.0763 - accuracy: 0.9873 - f1_m: 0.9875 - val_loss: 0.5060 - val_accuracy: 0.9246 - val_f1_m: 0.9247
#
# Epoch 00036: val_accuracy did not improve from 0.93822
# Epoch 37/50
# 348/348 [==============================] - 58s 168ms/step - loss: 0.0346 - accuracy: 0.9906 - f1_m: 0.9908 - val_loss: 0.3967 - val_accuracy: 0.9282 - val_f1_m: 0.9281
#
# Epoch 00037: val_accuracy did not improve from 0.93822
# Epoch 38/50
# 348/348 [==============================] - 58s 166ms/step - loss: 0.0447 - accuracy: 0.9933 - f1_m: 0.9932 - val_loss: 0.3246 - val_accuracy: 0.9379 - val_f1_m: 0.9380
#
# Epoch 00038: val_accuracy did not improve from 0.93822
# Epoch 39/50
# 348/348 [==============================] - 58s 166ms/step - loss: 0.0336 - accuracy: 0.9934 - f1_m: 0.9935 - val_loss: 0.4528 - val_accuracy: 0.9310 - val_f1_m: 0.9312
#
# Epoch 00039: val_accuracy did not improve from 0.93822
# Epoch 40/50
# 348/348 [==============================] - 57s 163ms/step - loss: 0.0223 - accuracy: 0.9948 - f1_m: 0.9948 - val_loss: 0.4098 - val_accuracy: 0.9318 - val_f1_m: 0.9322
#
# Epoch 00040: val_accuracy did not improve from 0.93822
# Epoch 41/50
# 348/348 [==============================] - 57s 164ms/step - loss: 0.0304 - accuracy: 0.9939 - f1_m: 0.9939 - val_loss: 0.3443 - val_accuracy: 0.9415 - val_f1_m: 0.9416
#
# Epoch 00041: val_accuracy improved from 0.93822 to 0.94145, saving model to model2_weights.h5
# Epoch 42/50
# 348/348 [==============================] - 58s 166ms/step - loss: 0.0289 - accuracy: 0.9942 - f1_m: 0.9941 - val_loss: 0.4296 - val_accuracy: 0.9353 - val_f1_m: 0.9355
#
# Epoch 00042: val_accuracy did not improve from 0.94145
# Epoch 43/50
# 348/348 [==============================] - 58s 166ms/step - loss: 0.0360 - accuracy: 0.9926 - f1_m: 0.9927 - val_loss: 0.5469 - val_accuracy: 0.9195 - val_f1_m: 0.9196
#
# Epoch 00043: val_accuracy did not improve from 0.94145
# Epoch 44/50
# 348/348 [==============================] - 58s 165ms/step - loss: 0.0417 - accuracy: 0.9907 - f1_m: 0.9908 - val_loss: 0.3421 - val_accuracy: 0.9318 - val_f1_m: 0.9318
#
# Epoch 00044: val_accuracy did not improve from 0.94145
# Epoch 45/50
# 348/348 [==============================] - 58s 165ms/step - loss: 0.0432 - accuracy: 0.9921 - f1_m: 0.9920 - val_loss: 0.3439 - val_accuracy: 0.9325 - val_f1_m: 0.9324
#
# Epoch 00045: val_accuracy did not improve from 0.94145
# Epoch 46/50
# 348/348 [==============================] - 58s 167ms/step - loss: 0.0356 - accuracy: 0.9941 - f1_m: 0.9941 - val_loss: 0.4876 - val_accuracy: 0.9318 - val_f1_m: 0.9321
#
# Epoch 00046: val_accuracy did not improve from 0.94145
# Epoch 47/50
# 348/348 [==============================] - 59s 170ms/step - loss: 0.0200 - accuracy: 0.9954 - f1_m: 0.9954 - val_loss: 0.3655 - val_accuracy: 0.9443 - val_f1_m: 0.9443
#
# Epoch 00047: val_accuracy improved from 0.94145 to 0.94432, saving model to model2_weights.h5
# Epoch 48/50
# 348/348 [==============================] - 57s 163ms/step - loss: 0.0264 - accuracy: 0.9950 - f1_m: 0.9951 - val_loss: 0.4270 - val_accuracy: 0.9418 - val_f1_m: 0.9418
#
# Epoch 00048: val_accuracy did not improve from 0.94432
# Epoch 49/50
# 348/348 [==============================] - 64s 183ms/step - loss: 0.0354 - accuracy: 0.9927 - f1_m: 0.9925 - val_loss: 0.3565 - val_accuracy: 0.9432 - val_f1_m: 0.9431
#
# Epoch 00049: val_accuracy did not improve from 0.94432
# Epoch 50/50
# 348/348 [==============================] - 57s 165ms/step - loss: 0.0578 - accuracy: 0.9901 - f1_m: 0.9902 - val_loss: 0.4955 - val_accuracy: 0.9343 - val_f1_m: 0.9344
#
# Epoch 00050: val_accuracy did not improve from 0.94432

# %%
IMG_SHAPE = (224, 224, 3)
base_model3 = keras.applications.resnet50.ResNet50(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')

# %%
base_model3.trainable = True

# %%
#Define the machine learning model
inputs = keras.Input(shape=(224, 224, 3))
# x = data_augmentation(inputs)
# x = preprocess_input(inputs)
x = base_model3(inputs)
x = layers.Flatten(name="flatten")(x)
x = layers.Dense(1024, activation="relu")(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(11, activation="softmax")(x)

model3 = keras.Model(inputs, outputs)

# %%
model3.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# resnet50 (Functional)        (None, 7, 7, 2048)        23587712
# _________________________________________________________________
# flatten (Flatten)            (None, 100352)            0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1024)              102761472
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 11)                11275
# =================================================================
# Total params: 126,360,459
# Trainable params: 126,307,339
# Non-trainable params: 53,120
# _________________________________________________________________

# %%
model3.compile(optimizers.Adam(learning_rate=0.0001, decay=1e-6),loss="categorical_crossentropy",metrics=["accuracy", f1_m])

# %%
checkpoint = ModelCheckpoint("model3_weights.h5", monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

# %%
#Train the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
STEP_SIZE_TEST=test_generator.n//test_generator.batch_size
hist3=model3.fit(train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    epochs=50,
                    callbacks = callbacks_list
)
# Out:
# Epoch 1/50
# 348/348 [==============================] - 79s 212ms/step - loss: 0.8497 - accuracy: 0.7777 - f1_m: 0.7766 - val_loss: 5.2256 - val_accuracy: 0.2364 - val_f1_m: 0.2273
#
# Epoch 00001: val_accuracy improved from -inf to 0.23635, saving model to model3_weights.h5
# /opt/conda/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/50
# 348/348 [==============================] - 73s 209ms/step - loss: 0.1591 - accuracy: 0.9412 - f1_m: 0.9410 - val_loss: 6.3838 - val_accuracy: 0.1081 - val_f1_m: 0.1041
#
# Epoch 00002: val_accuracy did not improve from 0.23635
# Epoch 3/50
# 348/348 [==============================] - 73s 209ms/step - loss: 0.0662 - accuracy: 0.9752 - f1_m: 0.9754 - val_loss: 1.5914 - val_accuracy: 0.5984 - val_f1_m: 0.6018
#
# Epoch 00003: val_accuracy improved from 0.23635 to 0.59842, saving model to model3_weights.h5
# Epoch 4/50
# 348/348 [==============================] - 73s 208ms/step - loss: 0.0596 - accuracy: 0.9799 - f1_m: 0.9805 - val_loss: 0.4630 - val_accuracy: 0.8380 - val_f1_m: 0.8408
#
# Epoch 00004: val_accuracy improved from 0.59842 to 0.83800, saving model to model3_weights.h5
# Epoch 5/50
# 348/348 [==============================] - 73s 208ms/step - loss: 0.0669 - accuracy: 0.9775 - f1_m: 0.9774 - val_loss: 0.4017 - val_accuracy: 0.8721 - val_f1_m: 0.8730
#
# Epoch 00005: val_accuracy improved from 0.83800 to 0.87213, saving model to model3_weights.h5
# Epoch 6/50
# 348/348 [==============================] - 77s 221ms/step - loss: 0.1005 - accuracy: 0.9698 - f1_m: 0.9697 - val_loss: 0.2746 - val_accuracy: 0.9120 - val_f1_m: 0.9116
#
# Epoch 00006: val_accuracy improved from 0.87213 to 0.91200, saving model to model3_weights.h5
# Epoch 7/50
# 348/348 [==============================] - 72s 208ms/step - loss: 0.0355 - accuracy: 0.9879 - f1_m: 0.9880 - val_loss: 0.2526 - val_accuracy: 0.9217 - val_f1_m: 0.9222
#
# Epoch 00007: val_accuracy improved from 0.91200 to 0.92170, saving model to model3_weights.h5
# Epoch 8/50
# 348/348 [==============================] - 73s 210ms/step - loss: 0.0238 - accuracy: 0.9926 - f1_m: 0.9925 - val_loss: 0.2392 - val_accuracy: 0.9278 - val_f1_m: 0.9279
#
# Epoch 00008: val_accuracy improved from 0.92170 to 0.92780, saving model to model3_weights.h5
# Epoch 9/50
# 348/348 [==============================] - 73s 208ms/step - loss: 0.0380 - accuracy: 0.9886 - f1_m: 0.9883 - val_loss: 0.3480 - val_accuracy: 0.9005 - val_f1_m: 0.9000
#
# Epoch 00009: val_accuracy did not improve from 0.92780
# Epoch 10/50
# 348/348 [==============================] - 73s 208ms/step - loss: 0.0502 - accuracy: 0.9851 - f1_m: 0.9850 - val_loss: 0.3628 - val_accuracy: 0.8969 - val_f1_m: 0.8977
#
# Epoch 00010: val_accuracy did not improve from 0.92780
# Epoch 11/50
# 348/348 [==============================] - 72s 208ms/step - loss: 0.0618 - accuracy: 0.9811 - f1_m: 0.9814 - val_loss: 0.2462 - val_accuracy: 0.9260 - val_f1_m: 0.9251
#
# Epoch 00011: val_accuracy did not improve from 0.92780
# Epoch 12/50
# 348/348 [==============================] - 73s 208ms/step - loss: 0.0675 - accuracy: 0.9799 - f1_m: 0.9799 - val_loss: 0.3593 - val_accuracy: 0.9052 - val_f1_m: 0.9056
#
# Epoch 00012: val_accuracy did not improve from 0.92780
# Epoch 13/50
# 348/348 [==============================] - 73s 208ms/step - loss: 0.0492 - accuracy: 0.9859 - f1_m: 0.9859 - val_loss: 0.3462 - val_accuracy: 0.9023 - val_f1_m: 0.9019
#
# Epoch 00013: val_accuracy did not improve from 0.92780
# Epoch 14/50
# 348/348 [==============================] - 73s 209ms/step - loss: 0.0251 - accuracy: 0.9925 - f1_m: 0.9925 - val_loss: 0.2620 - val_accuracy: 0.9350 - val_f1_m: 0.9352
#
# Epoch 00014: val_accuracy improved from 0.92780 to 0.93499, saving model to model3_weights.h5
# Epoch 15/50
# 348/348 [==============================] - 77s 221ms/step - loss: 0.0327 - accuracy: 0.9903 - f1_m: 0.9903 - val_loss: 0.4696 - val_accuracy: 0.8876 - val_f1_m: 0.8885
#
# Epoch 00015: val_accuracy did not improve from 0.93499
# Epoch 16/50
# 348/348 [==============================] - 73s 209ms/step - loss: 0.0444 - accuracy: 0.9871 - f1_m: 0.9872 - val_loss: 0.2691 - val_accuracy: 0.9335 - val_f1_m: 0.9339
#
# Epoch 00016: val_accuracy did not improve from 0.93499
# Epoch 17/50
# 348/348 [==============================] - 73s 210ms/step - loss: 0.0474 - accuracy: 0.9872 - f1_m: 0.9874 - val_loss: 0.2894 - val_accuracy: 0.9185 - val_f1_m: 0.9175
#
# Epoch 00017: val_accuracy did not improve from 0.93499
# Epoch 18/50
# 348/348 [==============================] - 77s 222ms/step - loss: 0.0332 - accuracy: 0.9904 - f1_m: 0.9905 - val_loss: 0.3380 - val_accuracy: 0.9267 - val_f1_m: 0.9263
#
# Epoch 00018: val_accuracy did not improve from 0.93499
# Epoch 19/50
# 348/348 [==============================] - 77s 222ms/step - loss: 0.0186 - accuracy: 0.9946 - f1_m: 0.9947 - val_loss: 0.3188 - val_accuracy: 0.9213 - val_f1_m: 0.9210
#
# Epoch 00019: val_accuracy did not improve from 0.93499
# Epoch 20/50
# 348/348 [==============================] - 73s 209ms/step - loss: 0.0132 - accuracy: 0.9955 - f1_m: 0.9955 - val_loss: 0.3704 - val_accuracy: 0.9264 - val_f1_m: 0.9266
#
# Epoch 00020: val_accuracy did not improve from 0.93499
# Epoch 21/50
# 348/348 [==============================] - 74s 211ms/step - loss: 0.0260 - accuracy: 0.9921 - f1_m: 0.9923 - val_loss: 0.6261 - val_accuracy: 0.8725 - val_f1_m: 0.8731
#
# Epoch 00021: val_accuracy did not improve from 0.93499
# Epoch 22/50
# 348/348 [==============================] - 73s 210ms/step - loss: 0.0470 - accuracy: 0.9879 - f1_m: 0.9878 - val_loss: 0.2737 - val_accuracy: 0.9239 - val_f1_m: 0.9240
#
# Epoch 00022: val_accuracy did not improve from 0.93499
# Epoch 23/50
# 348/348 [==============================] - 73s 208ms/step - loss: 0.0293 - accuracy: 0.9924 - f1_m: 0.9925 - val_loss: 0.3304 - val_accuracy: 0.9278 - val_f1_m: 0.9277
#
# Epoch 00023: val_accuracy did not improve from 0.93499
# Epoch 24/50
# 348/348 [==============================] - 73s 209ms/step - loss: 0.0281 - accuracy: 0.9931 - f1_m: 0.9931 - val_loss: 0.2882 - val_accuracy: 0.9310 - val_f1_m: 0.9314
#
# Epoch 00024: val_accuracy did not improve from 0.93499
# Epoch 25/50
# 348/348 [==============================] - 73s 209ms/step - loss: 0.0216 - accuracy: 0.9924 - f1_m: 0.9925 - val_loss: 0.2389 - val_accuracy: 0.9411 - val_f1_m: 0.9411
#
# Epoch 00025: val_accuracy improved from 0.93499 to 0.94109, saving model to model3_weights.h5
# Epoch 26/50
# 348/348 [==============================] - 73s 209ms/step - loss: 0.0320 - accuracy: 0.9915 - f1_m: 0.9916 - val_loss: 0.4578 - val_accuracy: 0.9167 - val_f1_m: 0.9166
#
# Epoch 00026: val_accuracy did not improve from 0.94109
# Epoch 27/50
# 348/348 [==============================] - 73s 208ms/step - loss: 0.0379 - accuracy: 0.9899 - f1_m: 0.9900 - val_loss: 0.3227 - val_accuracy: 0.9382 - val_f1_m: 0.9384
#
# Epoch 00027: val_accuracy did not improve from 0.94109
# Epoch 28/50
# 348/348 [==============================] - 73s 208ms/step - loss: 0.0336 - accuracy: 0.9928 - f1_m: 0.9928 - val_loss: 0.4320 - val_accuracy: 0.9045 - val_f1_m: 0.9045
#
# Epoch 00028: val_accuracy did not improve from 0.94109
# Epoch 29/50
# 348/348 [==============================] - 73s 209ms/step - loss: 0.0274 - accuracy: 0.9918 - f1_m: 0.9919 - val_loss: 0.3053 - val_accuracy: 0.9357 - val_f1_m: 0.9356
#
# Epoch 00029: val_accuracy did not improve from 0.94109
# Epoch 30/50
# 348/348 [==============================] - 73s 209ms/step - loss: 0.0138 - accuracy: 0.9962 - f1_m: 0.9962 - val_loss: 0.2744 - val_accuracy: 0.9425 - val_f1_m: 0.9426
#
# Epoch 00030: val_accuracy improved from 0.94109 to 0.94253, saving model to model3_weights.h5
# Epoch 31/50
# 348/348 [==============================] - 73s 209ms/step - loss: 0.0131 - accuracy: 0.9967 - f1_m: 0.9966 - val_loss: 0.3494 - val_accuracy: 0.9371 - val_f1_m: 0.9375
#
# Epoch 00031: val_accuracy did not improve from 0.94253
# Epoch 32/50
# 348/348 [==============================] - 73s 210ms/step - loss: 0.0059 - accuracy: 0.9982 - f1_m: 0.9982 - val_loss: 0.2907 - val_accuracy: 0.9443 - val_f1_m: 0.9443
#
# Epoch 00032: val_accuracy improved from 0.94253 to 0.94432, saving model to model3_weights.h5
# Epoch 33/50
# 348/348 [==============================] - 73s 210ms/step - loss: 0.0094 - accuracy: 0.9978 - f1_m: 0.9978 - val_loss: 0.3965 - val_accuracy: 0.9343 - val_f1_m: 0.9344
#
# Epoch 00033: val_accuracy did not improve from 0.94432
# Epoch 34/50
# 348/348 [==============================] - 73s 208ms/step - loss: 0.0148 - accuracy: 0.9965 - f1_m: 0.9965 - val_loss: 0.4642 - val_accuracy: 0.9152 - val_f1_m: 0.9153
#
# Epoch 00034: val_accuracy did not improve from 0.94432
# Epoch 35/50
# 348/348 [==============================] - 73s 209ms/step - loss: 0.0246 - accuracy: 0.9940 - f1_m: 0.9939 - val_loss: 0.3758 - val_accuracy: 0.9339 - val_f1_m: 0.9341
#
# Epoch 00035: val_accuracy did not improve from 0.94432
# Epoch 36/50
# 348/348 [==============================] - 73s 209ms/step - loss: 0.0206 - accuracy: 0.9945 - f1_m: 0.9943 - val_loss: 0.3422 - val_accuracy: 0.9386 - val_f1_m: 0.9386
#
# Epoch 00036: val_accuracy did not improve from 0.94432
# Epoch 37/50
# 348/348 [==============================] - 73s 209ms/step - loss: 0.0213 - accuracy: 0.9946 - f1_m: 0.9945 - val_loss: 0.3638 - val_accuracy: 0.9282 - val_f1_m: 0.9277
#
# Epoch 00037: val_accuracy did not improve from 0.94432
# Epoch 38/50
# 348/348 [==============================] - 73s 209ms/step - loss: 0.0239 - accuracy: 0.9933 - f1_m: 0.9934 - val_loss: 0.5165 - val_accuracy: 0.9113 - val_f1_m: 0.9110
#
# Epoch 00038: val_accuracy did not improve from 0.94432
# Epoch 39/50
# 348/348 [==============================] - 73s 209ms/step - loss: 0.0142 - accuracy: 0.9956 - f1_m: 0.9956 - val_loss: 0.3197 - val_accuracy: 0.9361 - val_f1_m: 0.9356
#
# Epoch 00039: val_accuracy did not improve from 0.94432
# Epoch 40/50
# 348/348 [==============================] - 73s 209ms/step - loss: 0.0214 - accuracy: 0.9944 - f1_m: 0.9944 - val_loss: 0.4743 - val_accuracy: 0.9145 - val_f1_m: 0.9154
#
# Epoch 00040: val_accuracy did not improve from 0.94432
# Epoch 41/50
# 348/348 [==============================] - 73s 209ms/step - loss: 0.0200 - accuracy: 0.9944 - f1_m: 0.9944 - val_loss: 0.3541 - val_accuracy: 0.9375 - val_f1_m: 0.9374
#
# Epoch 00041: val_accuracy did not improve from 0.94432
# Epoch 42/50
# 348/348 [==============================] - 73s 208ms/step - loss: 0.0196 - accuracy: 0.9958 - f1_m: 0.9957 - val_loss: 0.3343 - val_accuracy: 0.9368 - val_f1_m: 0.9371
#
# Epoch 00042: val_accuracy did not improve from 0.94432
# Epoch 43/50
# 348/348 [==============================] - 73s 209ms/step - loss: 0.0106 - accuracy: 0.9971 - f1_m: 0.9972 - val_loss: 0.3399 - val_accuracy: 0.9418 - val_f1_m: 0.9416
#
# Epoch 00043: val_accuracy did not improve from 0.94432
# Epoch 44/50
# 348/348 [==============================] - 73s 209ms/step - loss: 0.0080 - accuracy: 0.9976 - f1_m: 0.9976 - val_loss: 0.4459 - val_accuracy: 0.9357 - val_f1_m: 0.9360
#
# Epoch 00044: val_accuracy did not improve from 0.94432
# Epoch 45/50
# 348/348 [==============================] - 73s 209ms/step - loss: 0.0121 - accuracy: 0.9975 - f1_m: 0.9975 - val_loss: 0.3161 - val_accuracy: 0.9465 - val_f1_m: 0.9465
#
# Epoch 00045: val_accuracy improved from 0.94432 to 0.94648, saving model to model3_weights.h5
# Epoch 46/50
# 348/348 [==============================] - 73s 210ms/step - loss: 0.0100 - accuracy: 0.9969 - f1_m: 0.9968 - val_loss: 0.3447 - val_accuracy: 0.9425 - val_f1_m: 0.9434
#
# Epoch 00046: val_accuracy did not improve from 0.94648
# Epoch 47/50
# 348/348 [==============================] - 73s 209ms/step - loss: 0.0134 - accuracy: 0.9964 - f1_m: 0.9964 - val_loss: 0.3884 - val_accuracy: 0.9350 - val_f1_m: 0.9357
#
# Epoch 00047: val_accuracy did not improve from 0.94648
# Epoch 48/50
# 348/348 [==============================] - 73s 210ms/step - loss: 0.0193 - accuracy: 0.9957 - f1_m: 0.9958 - val_loss: 0.4031 - val_accuracy: 0.9235 - val_f1_m: 0.9242
#
# Epoch 00048: val_accuracy did not improve from 0.94648
# Epoch 49/50
# 348/348 [==============================] - 73s 209ms/step - loss: 0.0213 - accuracy: 0.9939 - f1_m: 0.9939 - val_loss: 0.5528 - val_accuracy: 0.9059 - val_f1_m: 0.9060
#
# Epoch 00049: val_accuracy did not improve from 0.94648
# Epoch 50/50
# 348/348 [==============================] - 73s 210ms/step - loss: 0.0279 - accuracy: 0.9939 - f1_m: 0.9937 - val_loss: 0.5243 - val_accuracy: 0.9210 - val_f1_m: 0.9216
#
# Epoch 00050: val_accuracy did not improve from 0.94648

# %%
model1.load_weights("./model1_weights.h5")

# %%
model2.load_weights("./model2_weights.h5")

# %%
model3.load_weights("./model3_weights.h5")

# %%
#Generate evaluation metric (validation loss, validation accuracy, validation f1-score)
model1.evaluate_generator(generator=valid_generator,steps=STEP_SIZE_VALID)
# Out:
# /opt/conda/lib/python3.7/site-packages/keras/engine/training.py:2006: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   warnings.warn('`Model.evaluate_generator` is deprecated and '
# [0.2884693741798401, 0.9461206793785095, 0.9464455842971802]

# %%
#Generate evaluation metric (validation loss, validation accuracy, validation f1-score)
model2.evaluate_generator(generator=valid_generator,steps=STEP_SIZE_VALID)
# Out:
# [0.3655073046684265, 0.9443247318267822, 0.9443247318267822]

# %%
#Generate evaluation metric (validation loss, validation accuracy, validation f1-score)
model3.evaluate_generator(generator=valid_generator,steps=STEP_SIZE_VALID)
# Out:
# /opt/conda/lib/python3.7/site-packages/keras/engine/training.py:2006: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   warnings.warn('`Model.evaluate_generator` is deprecated and '
# [0.3197309374809265, 0.9461206793785095, 0.9461206793785095]

# %%
from sklearn.metrics import accuracy_score

models = [model1, model2, model3]

preds = [model.predict(test_generator) for model in models]
preds = np.array(preds)
summed = np.sum(preds, axis=0)

# argmax across classes
ensemble_prediction = np.argmax(summed, axis=1)

# %%
#Define the labels prediction based on the index predictions
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in ensemble_prediction]

# %%
#Save the prediction using submission format
filenames=test_generator.filenames
results=pd.DataFrame({"data":filenames,"label":predictions})
results.to_csv("results.csv",mode='w', columns=['label'], index_label='index', index=True)
